# %%
import pandas as pd
import numpy as np

# %%
age = np.random.randint(10,100,15)

# %%
age
# Out:
# array([82, 13, 81, 86, 21, 14, 35, 27, 80, 12, 64, 11, 40, 52, 89])

# %%
s = pd.Series(age)

# %%
s.head()
# Out:
# 0    82
# 1    13
# 2    81
# 3    86
# 4    21
# dtype: int32

# %%
s.tail()
# Out:
# 10    64
# 11    11
# 12    40
# 13    52
# 14    89
# dtype: int32

# %%
s[0]
# Out:
# 82

# %%
s[0:5]
# Out:
# 0    82
# 1    13
# 2    81
# 3    86
# 4    21
# dtype: int32

# %%
data = {
    "scores" : np.random.randint(20,120,8),
    "names" : np.array(['Sachin','Dhoni','Kohli','Yuvraj','Raina','Rohit','Rishabh','Jadeja']),
    "catches" : np.random.randint(1,6,8),
    "average" : np.random.randint(40,55,8)
}

# %%
data
# Out:
# {'scores': array([ 23,  27,  71, 108,  87,  92, 116,  59]),
#  'names': array(['Sachin', 'Dhoni', 'Kohli', 'Yuvraj', 'Raina', 'Rohit', 'Rishabh',
#         'Jadeja'], dtype='<U7'),
#  'catches': array([2, 4, 2, 3, 5, 4, 2, 3]),
#  'average': array([54, 48, 49, 43, 48, 48, 54, 48])}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    scores    names  catches  average
# 0      23   Sachin        2       54
# 1      27    Dhoni        4       48
# 2      71    Kohli        2       49
# 3     108   Yuvraj        3       43
# 4      87    Raina        5       48
# 5      92    Rohit        4       48
# 6     116  Rishabh        2       54
# 7      59   Jadeja        3       48

# %%
df.head()
# Out:
#    scores   names  catches  average
# 0      23  Sachin        2       54
# 1      27   Dhoni        4       48
# 2      71   Kohli        2       49
# 3     108  Yuvraj        3       43
# 4      87   Raina        5       48

# %%
df[df['catches'] >= 4]
# Out:
#    scores  names  catches  average
# 1      27  Dhoni        4       48
# 4      87  Raina        5       48
# 5      92  Rohit        4       48

# %%
df[df['catches'] >= 4][['names','average']]
# Out:
#    names  average
# 1  Dhoni       48
# 4  Raina       48
# 5  Rohit       48
